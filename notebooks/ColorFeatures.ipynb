# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import os
import sys
sys.path.append(os.path.abspath('../'))
from tqdm import tqdm
from pathlib import Path
from collections import Counter
import multiprocessing as mp

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa import stattools
from scipy.stats import entropy, skew, kurtosis


from skin_lesion_cad.features.colour import ColorFeaturesExtractor

# %%
def process_img(x):
    img_path, mask_type = x
    img = cv2.imread(str(img_path))
    img = cv2.medianBlur(img, 3)
    
    if mask_type == 'ground_truth':
        mask = cv2.imread(str(img_path).replace('inpaint', 'mask'), cv2.IMREAD_GRAYSCALE)
    if mask_type == 'full_image':
        mask = np.ones(img.shape[:2], dtype=np.uint8)
    if isinstance(mask_type, int):
        mask = np.zeros(img.shape[:2], dtype=np.uint8)
        mask = cv2.circle(mask, (mask.shape[1]//2, mask.shape[0]//2), mask_type, 1, -1)

    img_name = img_path.name.split('_')[0]
    imf_fearures = cfe.extract_masked(img, mask)
    imf_fearures['name'] = img_name
    return imf_fearures

# %%
proc_data = Path().resolve().parent / 'data/processed'

color_spaces = {'bgr':cv2.COLOR_RGB2BGR, 'hsv':cv2.COLOR_RGB2HSV,  'YCrCb':cv2.COLOR_RGB2YCrCb}
mshift_params = {'sp': 10, 'sr': 15} # spatial and color range radius

# %% [markdown]
# # Data Extraction

# %%
chl = 'chall1'
mode = 'train'

mask_type = 'ground_truth'
for t in ['meanshift', 'raw', 'skincolnorm']:
    for cls in ['nevus', 'others']:

        test_path = proc_data / f'{chl}/{mode}/{cls}'
        
        if t == 'meanshift':
            cfe = ColorFeaturesExtractor(color_spaces, mshift_params)
            
        elif t == 'skincolnorm':
            cfe = ColorFeaturesExtractor(color_spaces, rel_col=True)
            
        else:
            cfe = ColorFeaturesExtractor(color_spaces)

        all_imgs = list(test_path.glob('*inpaint_0_5*'))[:5000]

        candidates_features = []
        with mp.Pool(8) as pool:
            for result in tqdm(pool.imap(process_img, zip(all_imgs, [mask_type]*len(all_imgs))), total=len(all_imgs)):
                candidates_features.append(result)
                
                
        df = pd.DataFrame(candidates_features).reset_index()
        df.to_feather(test_path.parent/f'{test_path.name}_color_features_{t}_{mask_type}.feather')
# Out:
# 100%|██████████| 5000/5000 [03:39<00:00, 22.78it/s]
# 100%|██████████| 5000/5000 [05:58<00:00, 13.93it/s]
# 100%|██████████| 5000/5000 [00:42<00:00, 117.40it/s]
# 100%|██████████| 5000/5000 [01:05<00:00, 76.20it/s]
#  53%|█████▎    | 2635/5000 [00:27<00:21, 107.86it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# 100%|██████████| 5000/5000 [00:52<00:00, 95.79it/s]
#   2%|▏         | 111/5000 [00:01<01:02, 78.84it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   9%|▉         | 447/5000 [00:08<01:29, 50.79it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# 100%|██████████| 5000/5000 [01:16<00:00, 65.49it/s]

# %%
def process_img(x):
    image_path, mask_type = x
    im = cv2.imread(str(image_path))  
    
    # im = im[im.shape[0]//4:im.shape[0]*3//4, im.shape[1]//4:im.shape[1]*3//4, :]
    fov = cv2.imread(str(image_path).replace('inpaint', 'fov'), cv2.IMREAD_GRAYSCALE)
    mask = 255*(fov == 0).astype(np.uint8)
    mcx, mcy = mask.shape[0]//2, mask.shape[1]//2
    if not np.any(mask[mcx - 10:mcx + 10, mcy - 10:mcy + 10]):
        mask = np.zeros(mask.shape, dtype=np.uint8)
        mask[im.shape[0]//4:im.shape[0]*3//4, im.shape[1]//4:im.shape[1]*3//4] = 255

    if 'bcc' in str(image_path):
        img_cls = 1
    elif 'mel' in str(image_path):
        img_cls = 0
    else:
        img_cls = 2
    
    imf_fearures = cfe.extract_masked(im, mask)
    
    img_name = image_path.name.split('_')[0]
    imf_fearures['name'] = img_name
    return imf_fearures

mask_type = 'ground_truth'

chl = 'chall2'
mode = 'train'

for t in ['meanshift', 'raw', 'skincolnorm']:
    for cls in ['bcc', 'scc', 'mel']:

        test_path = proc_data / f'{chl}/{mode}/{cls}'
        
        if t == 'meanshift':
            cfe = ColorFeaturesExtractor(color_spaces, mshift_params)
            
        elif t == 'skincolnorm':
            cfe = ColorFeaturesExtractor(color_spaces, rel_col=True)
            
        else:
            cfe = ColorFeaturesExtractor(color_spaces)

        all_imgs = list(test_path.glob('*inpaint_1*'))

        candidates_features = []
        with mp.Pool(8) as pool:
            for result in tqdm(pool.imap(process_img, zip(all_imgs, [mask_type]*len(all_imgs))), total=len(all_imgs)):
                candidates_features.append(result)
                
                
        df = pd.DataFrame(candidates_features).reset_index()
        df.to_feather(test_path.parent/f'{test_path.name}_color_features_{t}_{mask_type}.feather')
# Out:
# 100%|██████████| 1993/1993 [11:17<00:00,  2.94it/s]
# 100%|██████████| 376/376 [02:12<00:00,  2.85it/s]
# 100%|██████████| 2713/2713 [20:18<00:00,  2.23it/s]
# 100%|██████████| 1993/1993 [03:28<00:00,  9.56it/s]
# 100%|██████████| 376/376 [00:34<00:00, 10.89it/s]
# 100%|██████████| 2713/2713 [04:16<00:00, 10.59it/s]
#   0%|          | 0/1993 [00:00<?, ?it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   1%|          | 22/1993 [00:02<04:03,  8.08it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   1%|▏         | 28/1993 [00:03<02:55, 11.22it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   3%|▎         | 58/1993 [00:06<03:06, 10.38it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   3%|▎         | 68/1993 [00:07<03:55,  8.17it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   4%|▎         | 70/1993 [00:07<04:24,  7.27it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# 100%|██████████| 1993/1993 [03:13<00:00, 10.30it/s]
#   0%|          | 0/376 [00:00<?, ?it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   0%|          | 1/376 [00:00<01:39,  3.77it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   7%|▋         | 25/376 [00:02<00:27, 12.65it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   7%|▋         | 27/376 [00:02<00:34, 10.16it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# 100%|██████████| 376/376 [00:31<00:00, 11.97it/s]
#   0%|          | 0/2713 [00:00<?, ?it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   0%|          | 3/2713 [00:01<21:03,  2.14it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   1%|          | 17/2713 [00:01<03:14, 13.84it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   1%|          | 20/2713 [00:02<05:14,  8.55it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   1%|          | 23/2713 [00:02<04:52,  9.20it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#   2%|▏         | 56/2713 [00:05<02:57, 15.00it/s]/home/vzalevskyi/uni/MAIA_Semester_3/cad/skin-lesion-cad/skin_lesion_cad/features/colour.py:47: RuntimeWarning: Mean of empty slice.
#   non_leasion_means = img[mask==0].mean(axis=0)
# /home/vzalevskyi/anaconda3/envs/cad/lib/python3.10/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# 100%|██████████| 2713/2713 [03:45<00:00, 12.03it/s]

# %% [markdown]
# ### Showing intermididate results

# %%
all_imgs = list(test_path.glob('*inpaint_0_5*'))

timg = cv2.imread(str(all_imgs[0]))
timg = cv2.cvtColor(timg, cv2.COLOR_RGB2BGR)

mshift = cv2.pyrMeanShiftFiltering(timg, **mshift_params)

# %%
chl = 'chall1'
mode = 'train'
cls = 'nevus'

test_path = proc_data / f'{chl}/{mode}/{cls}'

for timgp in list(test_path.glob('*inpaint_0_5*'))[:10]:

    timg = cv2.imread(str(timgp))
    mask = cv2.imread(str(timgp).replace('inpaint', 'mask'), cv2.IMREAD_GRAYSCALE)

    timg = cv2.cvtColor(timg, cv2.COLOR_RGB2BGR)

    mshift = cv2.pyrMeanShiftFiltering(timg, **mshift_params)
    # non_leasion_means = timg[mask==0].mean(axis=0)
    # mshift = timg - non_leasion_means
    
    # mshift = (mshift - mshift.min())/(mshift.max() - mshift.min())
    fig, axs =plt.subplots(1, 3, figsize=(10, 5))

    axs[0].imshow(timg)
    axs[0].axis('off')
    axs[1].imshow(mshift)
    axs[1].axis('off')
    axs[2].imshow(mask)
    axs[2].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
# chl = 'chall1'
# mode = 'train'
# cls = 'others'

# test_path = proc_data / f'{chl}/{mode}/{cls}'

# for timgp in list(test_path.glob('*inpaint_0_5*'))[:10]:

#     timg = cv2.imread(str(timgp))
#     mask = cv2.imread(str(timgp).replace('inpaint', 'mask'), cv2.IMREAD_GRAYSCALE)

#     timg = cv2.cvtColor(timg, cv2.COLOR_RGB2BGR)

#     mshift = cv2.pyrMeanShiftFiltering(timg, **mshift_params)

#     fig, axs =plt.subplots(1, 3, figsize=(10, 5))

#     axs[0].imshow(timg)
#     axs[0].axis('off')
#     axs[1].imshow(mshift)
#     axs[1].axis('off')
#     axs[2].imshow(mask)
#     axs[2].axis('off')
    
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# # Data Analysis

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc, accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.decomposition import PCA

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_validate

import seaborn as sns

# from visualization.utils import plot_roc_curve, roc_auc_score_multiclass

# %% [markdown]
# ### Challenge 1

# %%
chl = 'chall1'
mode = 'train'

res = dict()

for feat_type in ['meanshift', 'raw', 'skincolnorm']:
    test_path = proc_data / f'{chl}/{mode}/{feat_type}'

    print('\nAnalyzing features for', feat_type)
    nevus_data = pd.read_feather(test_path.parent / f'nevus_color_features_{feat_type}_ground_truth.feather').set_index('name')
    nevus_data['class'] = 0
    others_data = pd.read_feather(test_path.parent/ f'others_color_features_{feat_type}_ground_truth.feather').set_index('name')
    others_data['class'] = 1

    data = pd.concat([nevus_data, others_data])

    all_X = data.drop(columns=['class']).values
    all_y = data['class'].values


    
    all_X[np.isnan(all_X)] = 0
    all_X[np.isinf(all_X)] = 0

    X_train, X_test, y_train, y_test = train_test_split(all_X, all_y, test_size=0.3, random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    res[feat_type] = cross_validate(SVC(), all_X, all_y, cv=5, scoring='accuracy')
    # svc = SVC(kernel='rbf', probability=True)
    # svc.fit(X_train, y_train)

    # y_pred = svc.predict(X_test)

    # print(classification_report(y_test, y_pred))
    # print('Confusion Matrix\n',confusion_matrix(y_test, y_pred))
    # print('\nAccuracy: ', accuracy_score(y_test, y_pred))
    # plot_roc_curve(y_test, svc.predict_proba(X_test)[:,1])
# Out:
# Analyzing features for meanshift
#
# Analyzing features for raw
#
# Analyzing features for skincolnorm

# %%
sns.boxplot(pd.DataFrame({k:v['test_score'] for k,v in res.items()}))
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
chl = 'chall1'
mode = 'train'



for feat_type in ['raw', 'meanshift', 'skincolnorm']:
    test_path = proc_data / f'{chl}/{mode}/{feat_type}'

    print('\nAnalyzing features for', feat_type)
    nevus_data = pd.read_feather(test_path.parent / f'nevus_color_features_{feat_type}.feather').set_index('name')
    nevus_data['class'] = 0
    others_data = pd.read_feather(test_path.parent/ f'others_color_features_{feat_type}.feather').set_index('name')
    others_data['class'] = 1

    data = pd.concat([nevus_data, others_data])

    all_X = data.drop(columns=['class']).values
    all_y = data['class'].values


    all_X[np.isnan(all_X)] = 0
    all_X[np.isinf(all_X)] = 0

    X_train, X_test, y_train, y_test = train_test_split(all_X, all_y, test_size=0.3, random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    svc = SVC(kernel='rbf', probability=True)
    svc.fit(X_train, y_train)

    y_pred = svc.predict(X_test)

    print(classification_report(y_test, y_pred))
    print('Confusion Matrix\n',confusion_matrix(y_test, y_pred))
    print('\nAccuracy: ', accuracy_score(y_test, y_pred))
    plot_roc_curve(y_test, svc.predict_proba(X_test)[:,1])
# Out:
# Analyzing features for raw
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78      2302
#            1       0.77      0.80      0.78      2257
#
#     accuracy                           0.78      4559
#    macro avg       0.78      0.78      0.78      4559
# weighted avg       0.78      0.78      0.78      4559
#
# Confusion Matrix
#  [[1763  539]
#  [ 456 1801]]
#
# Accuracy:  0.7817503838561088
# Analyzing features for meanshift
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96      2302
#            1       0.95      0.98      0.96      2257
#
#     accuracy                           0.96      4559
#    macro avg       0.96      0.96      0.96      4559
# weighted avg       0.96      0.96      0.96      4559
#
# Confusion Matrix
#  [[2190  112]
#  [  55 2202]]
#
# Accuracy:  0.9633691599034876
# Analyzing features for skincolnorm
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77      2302
#            1       0.77      0.76      0.77      2257
#
#     accuracy                           0.77      4559
#    macro avg       0.77      0.77      0.77      4559
# weighted avg       0.77      0.77      0.77      4559
#
# Confusion Matrix
#  [[1776  526]
#  [ 531 1726]]
#
# Accuracy:  0.7681509102873437

# %% [markdown]
# ### Challenge 2

# %%
chl = 'chall2'
mode = 'train'

res = dict()

for feat_type in ['meanshift', 'raw', 'skincolnorm']:
    test_path = proc_data / f'{chl}/{mode}/'

    print('\nAnalyzing features for', feat_type)
    bcc_data = pd.read_feather(test_path / f'bcc_color_features_{feat_type}_ground_truth.feather').set_index('name')
    bcc_data['class'] = 0
    
    mel_data = pd.read_feather(test_path/ f'mel_color_features_{feat_type}_ground_truth.feather').set_index('name')
    mel_data['class'] = 1
    
    scc_data = pd.read_feather(test_path/ f'scc_color_features_{feat_type}_ground_truth.feather').set_index('name')
    scc_data['class'] = 2
    
    data = pd.concat([scc_data, bcc_data, mel_data])

    all_X = data.drop(columns=['class']).values
    all_y = data['class'].values


    
    all_X[np.isnan(all_X)] = 0
    all_X[np.isinf(all_X)] = 0

    X_train, X_test, y_train, y_test = train_test_split(all_X, all_y, test_size=0.3, random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    res[feat_type] = cross_validate(SVC(class_weight='balanced'), all_X, all_y, cv=5, scoring='balanced_accuracy')
    # svc = SVC(kernel='rbf', probability=True)
    # svc.fit(X_train, y_train)

    # y_pred = svc.predict(X_test)

    # print(classification_report(y_test, y_pred))
    # print('Confusion Matrix\n',confusion_matrix(y_test, y_pred))
    # print('\nAccuracy: ', accuracy_score(y_test, y_pred))
    # plot_roc_curve(y_test, svc.predict_proba(X_test)[:,1])
# Out:
# Analyzing features for meanshift
#
# Analyzing features for raw
#
# Analyzing features for skincolnorm

# %%
sns.boxplot(pd.DataFrame({k:v['test_score'] for k,v in res.items()}))
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
chl = 'chall2'
mode = 'train'


for feat_type in ['raw', 'meanshift']:
    
    test_path = proc_data / f'{chl}/{mode}'
    print('\nAnalyzing features for', feat_type)
    
    bcc_data = pd.read_feather(test_path / f'bcc_color_features_{feat_type}_ull.feather').set_index('name')
    bcc_data['class'] = 0
    
    mel_data = pd.read_feather(test_path/ f'mel_color_features_{feat_type}_ull.feather').set_index('name')
    mel_data['class'] = 1
    
    scc_data = pd.read_feather(test_path/ f'scc_color_features_{feat_type}_ull.feather').set_index('name')
    scc_data['class'] = 2
    
    data = pd.concat([scc_data, bcc_data, mel_data])

    all_X = data.drop(columns=['class']).values
    all_y = data['class'].values
    

    all_X[np.isnan(all_X)] = 0
    all_X[np.isinf(all_X)] = 0
    
    split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
    train_idxs, test_idxs = next(split.split(all_X, all_y))
    X_train, X_test, y_train, y_test  = all_X[train_idxs], all_X[test_idxs], all_y[train_idxs], all_y[test_idxs]
    
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    svc = SVC(kernel='rbf', probability=True)
    svc.fit(X_train, y_train)

    y_pred = svc.predict(X_test)

    print(classification_report(y_test, y_pred))
    print('Confusion Matrix\n',confusion_matrix(y_test, y_pred))
    print('\nAccuracy', accuracy_score(y_test, y_pred))
    print('\nF1-score avg', f1_score(y_test, y_pred, average='weighted'))
    
    enc = OneHotEncoder()
    y_test_oh = enc.fit_transform(y_test.reshape(-1,1)).toarray()
    roc_auc_score_multiclass(svc, X_test, y_test_oh)
# Out:
# Analyzing features for raw
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79       598
#            1       0.85      0.88      0.86       814
#            2       0.67      0.02      0.03       113
#
#     accuracy                           0.80      1525
#    macro avg       0.75      0.58      0.56      1525
# weighted avg       0.79      0.80      0.77      1525
#
# Confusion Matrix
#  [[507  91   0]
#  [100 713   1]
#  [ 75  36   2]]
#
# Accuracy 0.801311475409836
#
# F1-score avg 0.7733879974237214
# Analyzing features for meanshift
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79       598
#            1       0.84      0.88      0.86       814
#            2       0.00      0.00      0.00       113
#
#     accuracy                           0.80      1525
#    macro avg       0.53      0.57      0.55      1525
# weighted avg       0.74      0.80      0.77      1525
#
# Confusion Matrix
#  [[505  93   0]
#  [101 713   0]
#  [ 74  39   0]]
#
# Accuracy 0.7986885245901639
#
# F1-score avg 0.7687047363148711

# %%
chl = 'chall2'
mode = 'train'


for feat_type in ['raw', 'meanshift', 'skincolnorm']:
    
    test_path = proc_data / f'{chl}/{mode}'
    print('\nAnalyzing features for', feat_type)
    
    bcc_data = pd.read_feather(test_path / f'bcc_color_features_{feat_type}.feather').set_index('name')
    bcc_data['class'] = 0
    
    mel_data = pd.read_feather(test_path/ f'mel_color_features_{feat_type}.feather').set_index('name')
    mel_data['class'] = 1
    
    scc_data = pd.read_feather(test_path/ f'scc_color_features_{feat_type}.feather').set_index('name')
    scc_data['class'] = 2
    
    data = pd.concat([scc_data, bcc_data, mel_data])

    all_X = data.drop(columns=['class']).values
    all_y = data['class'].values
    

    all_X[np.isnan(all_X)] = 0
    all_X[np.isinf(all_X)] = 0
    
    split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
    train_idxs, test_idxs = next(split.split(all_X, all_y))
    X_train, X_test, y_train, y_test  = all_X[train_idxs], all_X[test_idxs], all_y[train_idxs], all_y[test_idxs]
    
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    svc = SVC(kernel='rbf', probability=True)
    svc.fit(X_train, y_train)

    y_pred = svc.predict(X_test)

    print(classification_report(y_test, y_pred))
    print('Confusion Matrix\n',confusion_matrix(y_test, y_pred))
    print('\nAccuracy', accuracy_score(y_test, y_pred))
    print('\nF1-score avg', f1_score(y_test, y_pred, average='weighted'))
    
    enc = OneHotEncoder()
    y_test_oh = enc.fit_transform(y_test.reshape(-1,1)).toarray()
    roc_auc_score_multiclass(svc, X_test, y_test_oh)
# Out:
# Analyzing features for raw
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74       598
#            1       0.82      0.87      0.84       814
#            2       0.00      0.00      0.00       113
#
#     accuracy                           0.77      1525
#    macro avg       0.51      0.55      0.53      1525
# weighted avg       0.71      0.77      0.74      1525
#
# Confusion Matrix
#  [[467 131   0]
#  [106 708   0]
#  [ 84  29   0]]
#
# Accuracy 0.7704918032786885
#
# F1-score avg 0.741190383667179
# Analyzing features for meanshift
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75       598
#            1       0.82      0.86      0.84       814
#            2       0.00      0.00      0.00       113
#
#     accuracy                           0.77      1525
#    macro avg       0.51      0.55      0.53      1525
# weighted avg       0.71      0.77      0.74      1525
#
# Confusion Matrix
#  [[471 127   0]
#  [111 703   0]
#  [ 81  32   0]]
#
# Accuracy 0.7698360655737705
#
# F1-score avg 0.7407134412676876
# Analyzing features for skincolnorm
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vzalevskyi/anaconda3/envs/cad_skin/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.70      0.75      0.72       598
#            1       0.79      0.85      0.82       814
#            2       0.00      0.00      0.00       113
#
#     accuracy                           0.75      1525
#    macro avg       0.49      0.53      0.51      1525
# weighted avg       0.69      0.75      0.72      1525
#
# Confusion Matrix
#  [[447 151   0]
#  [119 695   0]
#  [ 76  37   0]]
#
# Accuracy 0.7488524590163934
#
# F1-score avg 0.7199213231923571

# %%
plt.hist(all_y)
plt.xticks([0,1,2], ['BCC', 'Mel', 'SCC'])
plt.show()
